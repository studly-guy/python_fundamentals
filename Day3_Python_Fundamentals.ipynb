# %%
Continution with String Data Type:

# %%
Introduction to f strings:

# %%
# General Syntax of f strings

# %%
f"custom message, {Place Holder -1} {Place Holder -2}...............{Place Holder -n}"

# %%
first_name = "Siva"
last_name = "Ganesh"

# %%
# Requirement is to get the full name

# %%
full_name =  f" My full name is {first_name.title()} {last_name.title()}"

print(full_name)
# Out:
#  My full name is Siva Ganesh

# %%
Adding white spaces to strings :

# %%
print("Favourite_Prog_lang: Python\nC++\nJava\nswift\nJavascript")
# Out:
# Favourite_Prog_lang: Python
# C++
# Java
# swift
# Javascript

# %%
/n acts as a delimiter and breaks the string as new lines

# %%
print("Favourite_Prog_lang: Python\n\tC++\n\tJava\n\tswift\n\tJavascript")
# Out:
# 		Favourite_Prog_lang: Python
# 	C++
# 	Java
# 	swift
# 	Javascript

# %%
\t as a tab space so in the result set there will be a space as you see in the above result set

# %%
Removing white spaces from the strings

# %%
name = "     python"

print(name.lstrip())
# Out:
# python

# %%
name2 = "python     "

print(name2)
# Out:
# python

# %%
name.lstrip()
# Out:
# 'python'

# %%
name2.rstrip()
# Out:
# 'python'

# %%
name3 = "      python           "

print(name3)
# Out:
#       python

# %%
name3.strip()
# Out:
# 'python'

# %%
print(name3.strip())
# Out:
# python

# %%
# ZEN of python :

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
