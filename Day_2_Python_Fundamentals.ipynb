# %% [markdown]
# Introduction to Python Programming

# %% [markdown]
# Understanding variables in python

# %%
a = 2
b = 3

# %%
c = a + b

print(c)
# Out:
# 5

# %%
Rules for declaring variables in python

1) Rule No 1: No Namespace while declaring the variable name

# %%
first_name = 'Siva'
print(first_name)
# Out:
#   Cell In[6], line 1
#     1_first_name = 'Siva'
#      ^
# SyntaxError: invalid decimal literal

# %%
Rule No 2: A variable name should not start with a number **

# %%
name_1 = "Siva"
print(name_1)
# Out:
# Siva

# %%
Rule No 3: A variable should not contain any special character

# %%
#, $, %

# %%
name@ = "Siva"
print(name@)
# Out:
#   Cell In[9], line 1
#     name@ = "Siva"
#           ^
# SyntaxError: invalid syntax

# %%
Introduction to data types in python

# %%
1) String  --------> str

2) Numbers----------> int, float

3)lists --------> list

4) tuples -------> tuple

5) Dictionaries ---------> dict

# %%
Note: Python programming is a case sensitive programming language **

# %%
classificatin of data types :

     Broadly data types are classified into two types:
       1) mutable datatypes ---> able to edit and alter --> flexible in nature
       2) immutable dataytypes ---> unable to edit and alter  --> fixed in nature

# %%
Introductiont to string datatype:

# %%
Definition: A string is nothing but a series of characters declared in quotes:

Classification:  Imutable datatype

How do you define the string datatype:
    1) single quote
    2) double quote

# %%
name = 'Siva'

name2 = "Ganesh"

print(name,",",name2)
# Out:
# Siva , Ganesh

# %%
Introduction to string methods

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
fullname = 'Siva Ganesh'

print(fullname)
# Out:
# Siva Ganesh

# %%
print(fullname.title())
# Out:
# Siva Ganesh

# %%
#Entire name in upper case

# %%
print(fullname.upper())
# Out:
# SIVA GANESH

# %%
#Entire name in lower case

# %%
print(fullname.lower())
# Out:
# siva ganesh
